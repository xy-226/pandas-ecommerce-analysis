# %%
import pandas as pd

df = pd.read_csv(r"D:\project\pandas-ecommerce-analysis\data\raw\Pakistan Largest Ecommerce Dataset.csv",
encoding='latin1'
)
df.head()
# Out:
# C:\Users\37450\AppData\Local\Temp\ipykernel_28392\3062179304.py:3: DtypeWarning: Columns (0: increment_id) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"D:\project\pandas-ecommerce-analysis\data\raw\Pakistan Largest Ecommerce Dataset.csv",
#    item_id          status created_at  \
# 0   211131        complete   7/1/2016
# 1   211133        canceled   7/1/2016
# 2   211134        canceled   7/1/2016
# 3   211135        complete   7/1/2016
# 4   211136  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0            1
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0            1
# 2                                 Ego_UP0017-999-MR0  2450.0            1
# 3                                     kcc_krone deal   360.0            1
# 4                                        BK7010400AG   555.0            2
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
# 2       2450.0    100147445    Women's Fashion                    \N  ...
# 3         60.0    100147446  Beauty & Grooming           R-FSD-52352  ...
# 4       1110.0    100147447            Soghaat                    \N  ...
#
#    payment_method Working Date BI Status    MV   Year  Month  Customer Since  \
# 0             cod     7/1/2016     #REF!  1,950  2016      7          Jul-16
# 1             cod     7/1/2016     Gross    240  2016      7          Jul-16
# 2             cod     7/1/2016     Gross  2,450  2016      7          Jul-16
# 3             cod     7/1/2016       Net    360  2016      7          Jul-16
# 4             cod     7/1/2016     Valid  1,110  2016      7          Jul-16
#
#       M-Y    FY Customer ID
# 0  7-2016  FY17         1.0
# 1  7-2016  FY17         2.0
# 2  7-2016  FY17         3.0
# 3  7-2016  FY17         4.0
# 4  7-2016  FY17         5.0
#
# [5 rows x 21 columns]

# %%
df["new_col"] = 1
df.head()
# Out:
#    item_id          status created_at  \
# 0   211131        complete   7/1/2016
# 1   211133        canceled   7/1/2016
# 2   211134        canceled   7/1/2016
# 3   211135        complete   7/1/2016
# 4   211136  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0            1
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0            1
# 2                                 Ego_UP0017-999-MR0  2450.0            1
# 3                                     kcc_krone deal   360.0            1
# 4                                        BK7010400AG   555.0            2
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
# 2       2450.0    100147445    Women's Fashion                    \N  ...
# 3         60.0    100147446  Beauty & Grooming           R-FSD-52352  ...
# 4       1110.0    100147447            Soghaat                    \N  ...
#
#    Working Date BI Status    MV   Year Month  Customer Since     M-Y    FY  \
# 0      7/1/2016     #REF!  1,950  2016     7          Jul-16  7-2016  FY17
# 1      7/1/2016     Gross    240  2016     7          Jul-16  7-2016  FY17
# 2      7/1/2016     Gross  2,450  2016     7          Jul-16  7-2016  FY17
# 3      7/1/2016       Net    360  2016     7          Jul-16  7-2016  FY17
# 4      7/1/2016     Valid  1,110  2016     7          Jul-16  7-2016  FY17
#
#   Customer ID new_col
# 0         1.0       1
# 1         2.0       1
# 2         3.0       1
# 3         4.0       1
# 4         5.0       1
#
# [5 rows x 22 columns]

# %%
import sys
print(sys.executable)
# Out:
# d:\project\pandas-ecommerce-analysis\.venv\Scripts\python.exe
